# %% [markdown]
# <a href="https://colab.research.google.com/github/phyo-thandar/MMDT_T-PY101_Batch03/blob/main/Phyo_Thandar_Hlaing/Ex1_Python_phyo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
sys.version

import numpy as np
import pandas as pd

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD: 3200
# 3200 usd is equivalent to 2624.0 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
temp_F = input("Enter the amount in Feranhite: ")
temp_C = (int(temp_F) - 32)/ 1.8
print("{} Feranhite is equilavent to {} Celsius.".format(temp_F,temp_C))
# Out:
# Enter the amount in Feranhite: 97
# 97 Feranhite is equilavent to 36.11111111111111 Celsius.

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple_quantity = input("Enter the quantity of apple: ")
apple_price = input("Enter the price of apple: ")
Total_Cost_apple = int(apple_quantity) * int(apple_price)

orange_quantity = input("Enter the quantity of orange: ")
orange_price = input("Enter the price of orange: ")
Total_Cost_orange = int(orange_quantity) * int(orange_price)

mango_quantity = input("Enter the quantity of mango: ")
mango_price = input("Enter the price of mango: ")
Total_Cost_mango = int(mango_quantity) * int (mango_price)

Total_Cost = Total_Cost_apple + Total_Cost_orange + Total_Cost_mango

print("Total cost of fruits is {}".format(Total_Cost))
# Out:
# Enter the quantity of apple: 5
# Enter the price of apple: 80
# Enter the quantity of orange: 10
# Enter the price of orange: 100
# Enter the quantity of mango: 3
# Enter the price of mango: 120
# Total cost of fruits is 1760

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
customer_name = input("Enter customer name: ")
print("Hello " + customer_name)
# Out:
# Enter customer name: Ms. Wah Wah
# Hello Ms. Wah Wah

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
print('A random number between 1 and 50: ', x)

y = randint(2,5)
print('A random number between 2 and 5: ', y)

z = x**y
print(z)
# Out:
# A random number between 1 and 50:  15
# A random number between 2 and 5:  3
# 3375

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
x = randint(1,10)
my_name = " Phyo "

print (x * my_name)
# Out:
#  Phyo  Phyo  Phyo  Phyo  Phyo  Phyo  Phyo  Phyo

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = input("Enter x: ")
y = input("Enter y: ")
Computation = abs(int(x)-int(y))/int(x)+int(y)
print(int(Computation))
# Out:
# Enter x: 12
# Enter y: 24
# 25

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
seconds = input("Enter the number of seconds: ")
Converted_minutes = int(int(seconds)/60)
Converted_seconds = int(seconds) - (Converted_minutes*60)

print("The number of minutes and seconds is {} minutes and {} seconds.".format(Converted_minutes,Converted_seconds))
# Out:
# Enter the number of seconds: 280
# The number of minutes and seconds is 4 minutes and 40 seconds.

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
num = float(input("Enter a number:"))
sine_value = math.sin(num)
print(sine_value)

cosine_value = math.cos(num)
print(cosine_value)

tangent_value = sine_value/cosine_value
print(tangent_value)
# Out:
# Enter a number:34
# 0.5290826861200238
# -0.8485702747846052
# -0.6234989627162255
